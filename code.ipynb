# %%
# import csv
# import requests
# from bs4 import BeautifulSoup
# with open ('agri.csv')as file:
#         csv_reader=csv.reader(file)
#         r=1
#         for row in csv_reader:
#             print(csv_reader)
#             url=row[1]
#             try:
#                 response=requests.get(str(url))
#                 soup=BeautifulSoup(response.content,'html.parser')
#                 agriculture11_info=soup.find_all.p.text
#                 print( agriculture11_info)
#                 if(response.status_code!=200):
#                     print("Error at code",r,response.status_code)
#             except:
#                 print(agriculture11_info,r)
#             r+=1

# %%
import csv
import requests
from bs4 import BeautifulSoup
with open('agri.csv','r') as f:
    lines=f.read().split('\n')
    lines=[l for l in lines if len(l)>0]
#     print(lines)
    r=1
    for row in lines:
            url=row[1]
            
            try:
                response=requests.get(str(url))
                soup=BeautifulSoup(response.content,'html.parser')
                agriculture11_info=soup.find_all.p.text
#                 print( agriculture11_info)
                if(response.status_code!=200):
                    print("Error at code",r,response.status_code)
            except:
#                 print(agriculture11_info,r)
                  print("erroe")
            r+=1
# Out:
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# erroe
# ...

# %%
# lines=f.read().split('\n')
# print(lines)

# %%
import json
response=requests.get(row)
soup=BeautifulSoup(response.content,'html.parser')
agriculture11_info=soup.find_all('p')
type(agriculture11_info[0].text)
str(agriculture11_info)
# final = []
for row in lines:
    url=row[1]

    for i in agriculture11_info:
        agriculture11_info=soup.find_all('p')
#         final.append(agriculture11_info)
#         listToStr = ' '.join(map(str,final))
#         print(final)
#         print(agriculture11_info)
#         a=agriculture11_info.text
#         print(a)
with open('agriculture.json', 'w') as file:
#     file.write(str(final))
    json.loads(agriculture11_info)
    json.dump(agriculture11_info,file)
    print('Your file is now ready')

#         print(a)
            
        


# for row in lines:
#     agriculture11_info=soup.find_all.p.text
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      71
# ---> 72     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73         af, socktype, proto, canonname, sa = res
#
# C:\ProgramData\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# ...

# %%
response=requests.get(row)
soup=BeautifulSoup(response.content,'html.parser')
agriculture11_info=soup.find_all('p')
for row in lines:
    url=row[1]

    for i in agriculture11_info:
        agriculture11_info=soup.find_all('p')
        print(agriculture11_info)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      71
# ---> 72     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73         af, socktype, proto, canonname, sa = res
#
# C:\ProgramData\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# ...

# %%
# response=requests.get(url,'utf8')
# soup=BeautifulSoup(response.content,'html.parser')
# agriculture11_info=soup.find_all.p.text
# print( agriculture11_info)

# %%
for i in agriculture11_info:
    a=i.text
#     print(a)

# %%
len(a)

# %%
 print(a)

# %%
out_file = open("agriculture.json", "w")
json.dump(a, out_file, indent = 4, sort_keys = False)
out_file.close()

# %%
def write_json(new_data,filename='agriculture.json'):
    with open(filename,'r+')as f:
        for row in lines:
            url=row[1]
            for i in agriculture11_info:
                a=i.text
#                 f.write(str(a))
                print(a)

            
        
#         file_data=json.Load(f)
#         file_data["emp_details"].append(new_data)
#         file.seek(0)
#         json.dump(file_data,file)

write_json(a)

# %%
import json
with open('agriculture.json', 'w') as f:     
    json.dump(a, f)
write_json(a)

# %%
 print(csv_reader)

# %%
print(lines)
lines=[l for l in lines if len(l)>0]

# %%
with open('agri.csv','r') as f:
    lines=f.read().split('\n')

# %%
print(lines)
